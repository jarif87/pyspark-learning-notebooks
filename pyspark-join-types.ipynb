# %%
! pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.3.tar.gz (317.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.3/317.3 MB 3.9 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /opt/conda/lib/python3.10/site-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.3-py2.py3-none-any.whl size=317840629 sha256=86d8d381e2ee5369312c9345606b251fcfae56aa193d298990155d30f8bc41af
#   Stored in directory: /root/.cache/pip/wheels/1b/3a/92/28b93e2fbfdbb07509ca4d6f50c5e407f48dce4ddbda69a4ab
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.3

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Employee Data") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/11/21 15:17:26 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
emp = [(1,"Smith",-1,"2018","10","M",3000), \
    (2,"Rose",1,"2010","20","M",4000), \
    (3,"Williams",1,"2010","10","M",1000), \
    (4,"Jones",2,"2005","10","F",2000), \
    (5,"Brown",2,"2010","40","",-1), \
      (6,"Brown",2,"2010","50","",-1) \
  ]

empColumns = ["emp_id","name","superior_emp_id","year_joined", \
       "emp_dept_id","gender","salary"]
empDF = spark.createDataFrame(data=emp, schema = empColumns)
empDF.show(truncate=False)
# Out:
# +------+--------+---------------+-----------+-----------+------+------+
# |emp_id|name    |superior_emp_id|year_joined|emp_dept_id|gender|salary|
# +------+--------+---------------+-----------+-----------+------+------+
# |1     |Smith   |-1             |2018       |10         |M     |3000  |
# |2     |Rose    |1              |2010       |20         |M     |4000  |
# |3     |Williams|1              |2010       |10         |M     |1000  |
# |4     |Jones   |2              |2005       |10         |F     |2000  |
# |5     |Brown   |2              |2010       |40         |      |-1    |
# |6     |Brown   |2              |2010       |50         |      |-1    |
# +------+--------+---------------+-----------+-----------+------+------+

# %%
empDF.printSchema()
# Out:
# root
#  |-- emp_id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- superior_emp_id: long (nullable = true)
#  |-- year_joined: string (nullable = true)
#  |-- emp_dept_id: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: long (nullable = true)

# %%
dept = [("Finance",10), \
    ("Marketing",20), \
    ("Sales",30), \
    ("IT",40) \
  ]
deptColumns = ["dept_name","dept_id"]
deptDF = spark.createDataFrame(data=dept, schema = deptColumns)
deptDF.printSchema()
deptDF.show(truncate=False)
# Out:
# root
#  |-- dept_name: string (nullable = true)
#  |-- dept_id: long (nullable = true)
#
# +---------+-------+
# |dept_name|dept_id|
# +---------+-------+
# |Finance  |10     |
# |Marketing|20     |
# |Sales    |30     |
# |IT       |40     |
# +---------+-------+

# %% [markdown]
# # PySpark Inner Join DataFrame

# %%
empDF.join(deptDF,empDF.emp_dept_id ==  deptDF.dept_id,"inner") \
     .show(truncate=False)
# Out:
# [Stage 5:=============================>                             (2 + 2) / 4]
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |emp_id|name    |superior_emp_id|year_joined|emp_dept_id|gender|salary|dept_name|dept_id|
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |1     |Smith   |-1             |2018       |10         |M     |3000  |Finance  |10     |
# |3     |Williams|1              |2010       |10         |M     |1000  |Finance  |10     |
# |4     |Jones   |2              |2005       |10         |F     |2000  |Finance  |10     |
# |2     |Rose    |1              |2010       |20         |M     |4000  |Marketing|20     |
# |5     |Brown   |2              |2010       |40         |      |-1    |IT       |40     |
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+

# %% [markdown]
# # Left outer join

# %%
empDF.join(deptDF,empDF.emp_dept_id ==  deptDF.dept_id,"left").show(truncate=False)
# Out:
# [Stage 28:=============================>                            (2 + 2) / 4]
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |emp_id|name    |superior_emp_id|year_joined|emp_dept_id|gender|salary|dept_name|dept_id|
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |1     |Smith   |-1             |2018       |10         |M     |3000  |Finance  |10     |
# |3     |Williams|1              |2010       |10         |M     |1000  |Finance  |10     |
# |2     |Rose    |1              |2010       |20         |M     |4000  |Marketing|20     |
# |4     |Jones   |2              |2005       |10         |F     |2000  |Finance  |10     |
# |6     |Brown   |2              |2010       |50         |      |-1    |NULL     |NULL   |
# |5     |Brown   |2              |2010       |40         |      |-1    |IT       |40     |
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+

# %%
empDF.join(deptDF,empDF.emp_dept_id ==  deptDF.dept_id,"leftouter").show(truncate=False)
# Out:
# [Stage 22:>                                                         (0 + 4) / 4]
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |emp_id|name    |superior_emp_id|year_joined|emp_dept_id|gender|salary|dept_name|dept_id|
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |1     |Smith   |-1             |2018       |10         |M     |3000  |Finance  |10     |
# |3     |Williams|1              |2010       |10         |M     |1000  |Finance  |10     |
# |2     |Rose    |1              |2010       |20         |M     |4000  |Marketing|20     |
# |4     |Jones   |2              |2005       |10         |F     |2000  |Finance  |10     |
# |6     |Brown   |2              |2010       |50         |      |-1    |NULL     |NULL   |
# |5     |Brown   |2              |2010       |40         |      |-1    |IT       |40     |
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+

# %% [markdown]
# # Right outer join

# %%
empDF.join(deptDF,empDF.emp_dept_id ==  deptDF.dept_id,"right") \
   .show(truncate=False)
# Out:
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |emp_id|name    |superior_emp_id|year_joined|emp_dept_id|gender|salary|dept_name|dept_id|
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |4     |Jones   |2              |2005       |10         |F     |2000  |Finance  |10     |
# |3     |Williams|1              |2010       |10         |M     |1000  |Finance  |10     |
# |1     |Smith   |-1             |2018       |10         |M     |3000  |Finance  |10     |
# |2     |Rose    |1              |2010       |20         |M     |4000  |Marketing|20     |
# |NULL  |NULL    |NULL           |NULL       |NULL       |NULL  |NULL  |Sales    |30     |
# |5     |Brown   |2              |2010       |40         |      |-1    |IT       |40     |
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+

# %%
empDF.join(deptDF,empDF.emp_dept_id ==  deptDF.dept_id,"rightouter") \
   .show(truncate=False)
# Out:
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |emp_id|name    |superior_emp_id|year_joined|emp_dept_id|gender|salary|dept_name|dept_id|
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |4     |Jones   |2              |2005       |10         |F     |2000  |Finance  |10     |
# |3     |Williams|1              |2010       |10         |M     |1000  |Finance  |10     |
# |1     |Smith   |-1             |2018       |10         |M     |3000  |Finance  |10     |
# |2     |Rose    |1              |2010       |20         |M     |4000  |Marketing|20     |
# |NULL  |NULL    |NULL           |NULL       |NULL       |NULL  |NULL  |Sales    |30     |
# |5     |Brown   |2              |2010       |40         |      |-1    |IT       |40     |
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+

# %% [markdown]
# # PySpark Full Outer Join

# %%
empDF.join(deptDF,empDF.emp_dept_id ==  deptDF.dept_id,"outer") \
    .show(truncate=False)
# Out:
# [Stage 46:===========================================>              (3 + 1) / 4]
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |emp_id|name    |superior_emp_id|year_joined|emp_dept_id|gender|salary|dept_name|dept_id|
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |1     |Smith   |-1             |2018       |10         |M     |3000  |Finance  |10     |
# |3     |Williams|1              |2010       |10         |M     |1000  |Finance  |10     |
# |4     |Jones   |2              |2005       |10         |F     |2000  |Finance  |10     |
# |2     |Rose    |1              |2010       |20         |M     |4000  |Marketing|20     |
# |NULL  |NULL    |NULL           |NULL       |NULL       |NULL  |NULL  |Sales    |30     |
# |5     |Brown   |2              |2010       |40         |      |-1    |IT       |40     |
# |6     |Brown   |2              |2010       |50         |      |-1    |NULL     |NULL   |
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+

# %%
empDF.join(deptDF,empDF.emp_dept_id ==  deptDF.dept_id,"full") \
    .show(truncate=False)
# Out:
# [Stage 51:==============>                                           (1 + 3) / 4]
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |emp_id|name    |superior_emp_id|year_joined|emp_dept_id|gender|salary|dept_name|dept_id|
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |1     |Smith   |-1             |2018       |10         |M     |3000  |Finance  |10     |
# |3     |Williams|1              |2010       |10         |M     |1000  |Finance  |10     |
# |4     |Jones   |2              |2005       |10         |F     |2000  |Finance  |10     |
# |2     |Rose    |1              |2010       |20         |M     |4000  |Marketing|20     |
# |NULL  |NULL    |NULL           |NULL       |NULL       |NULL  |NULL  |Sales    |30     |
# |5     |Brown   |2              |2010       |40         |      |-1    |IT       |40     |
# |6     |Brown   |2              |2010       |50         |      |-1    |NULL     |NULL   |
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+

# %%
empDF.join(deptDF,empDF.emp_dept_id ==  deptDF.dept_id,"fullouter") \
    .show(truncate=False)
# Out:
# [Stage 56:=============================>                            (2 + 2) / 4]
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |emp_id|name    |superior_emp_id|year_joined|emp_dept_id|gender|salary|dept_name|dept_id|
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+
# |1     |Smith   |-1             |2018       |10         |M     |3000  |Finance  |10     |
# |3     |Williams|1              |2010       |10         |M     |1000  |Finance  |10     |
# |4     |Jones   |2              |2005       |10         |F     |2000  |Finance  |10     |
# |2     |Rose    |1              |2010       |20         |M     |4000  |Marketing|20     |
# |NULL  |NULL    |NULL           |NULL       |NULL       |NULL  |NULL  |Sales    |30     |
# |5     |Brown   |2              |2010       |40         |      |-1    |IT       |40     |
# |6     |Brown   |2              |2010       |50         |      |-1    |NULL     |NULL   |
# +------+--------+---------------+-----------+-----------+------+------+---------+-------+

# %% [markdown]
# # Left Semi Join

# %%
empDF.join(deptDF,empDF.emp_dept_id ==  deptDF.dept_id,"leftsemi") \
   .show(truncate=False)
# Out:
# [Stage 61:>                                                         (0 + 4) / 4]
# +------+--------+---------------+-----------+-----------+------+------+
# |emp_id|name    |superior_emp_id|year_joined|emp_dept_id|gender|salary|
# +------+--------+---------------+-----------+-----------+------+------+
# |1     |Smith   |-1             |2018       |10         |M     |3000  |
# |3     |Williams|1              |2010       |10         |M     |1000  |
# |4     |Jones   |2              |2005       |10         |F     |2000  |
# |2     |Rose    |1              |2010       |20         |M     |4000  |
# |5     |Brown   |2              |2010       |40         |      |-1    |
# +------+--------+---------------+-----------+-----------+------+------+

# %% [markdown]
# # Left Anti Join

# %%
empDF.join(deptDF,empDF.emp_dept_id ==  deptDF.dept_id,"leftanti") \
   .show(truncate=False)
# Out:
# +------+-----+---------------+-----------+-----------+------+------+
# |emp_id|name |superior_emp_id|year_joined|emp_dept_id|gender|salary|
# +------+-----+---------------+-----------+-----------+------+------+
# |6     |Brown|2              |2010       |50         |      |-1    |
# +------+-----+---------------+-----------+-----------+------+------+

# %% [markdown]
# # PySpark Self Join

# %%
from pyspark.sql import functions as F

empDF.alias("emp1").join(empDF.alias("emp2"), 
    F.col("emp1.superior_emp_id") == F.col("emp2.emp_id"), "inner") \
    .select(
        F.col("emp1.emp_id"),
        F.col("emp1.name"),
        F.col("emp2.emp_id").alias("superior_emp_id"),
        F.col("emp2.name").alias("superior_emp_name")
    ) \
    .show(truncate=False)
# Out:
# [Stage 72:>                                                         (0 + 4) / 4]
# +------+--------+---------------+-----------------+
# |emp_id|name    |superior_emp_id|superior_emp_name|
# +------+--------+---------------+-----------------+
# |2     |Rose    |1              |Smith            |
# |3     |Williams|1              |Smith            |
# |4     |Jones   |2              |Rose             |
# |5     |Brown   |2              |Rose             |
# |6     |Brown   |2              |Rose             |
# +------+--------+---------------+-----------------+
